# %%
import pickle
import pandas as pd

# %%
# !ls -alt | head -6

# %%
with open(r'01_Jul_25_Texas_Warn.pkl', 'rb') as ifile:
    xxx = pickle.load(ifile)

# %%
xxx.info()

# %%
with open(r'01_Jul_25_Texas_Warn.pkl', 'rb') as ifile:
    xxx = pickle.load(ifile)

# %%
xxx.info()

# %%
xxx.loc[:, 'LayOff_Date_dt'] = pd.to_datetime(xxx.LayOff_Date, errors='coerce')

# %%
xxx.LayOff_Date_dt.values.sort()

# %%
xxx.LayOff_Date_dt

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
xxx[xxx.LayOff_Date_dt > '2025-05-01']
